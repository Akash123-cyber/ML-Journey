# %% [markdown]
# # 📊 Scikit-learn Preloaded Datasets Summary
#
# Scikit-learn (`sklearn.datasets`) comes with several **preloaded datasets** for quick experimentation and learning.
# Below is a detailed table showing their **type**, **usage**, **description**, and whether they are **synthetic** or **real-world**.
#
# | 🧩 Dataset | 🧠 Type | 📈 Suitable For | 🧾 Description | 🌍 Data Origin |
# |-------------|----------|----------------|----------------|----------------|
# | **Iris** | Multiclass Classification | Logistic Regression, KNN, SVM | Classify iris flowers into 3 species based on petal/sepal measurements. | 🌍 Real-world |
# | **Wine** | Multiclass Classification | Logistic Regression, Random Forest, SVM | Predict the origin of wines using chemical composition attributes. | 🌍 Real-world |
# | **Breast Cancer (Wisconsin)** | Binary Classification | Logistic Regression, Decision Trees | Detect whether a tumor is malignant or benign based on cell nucleus features. | 🌍 Real-world |
# | **Digits** | Multiclass Classification | Logistic Regression, Neural Nets | Handwritten digits (0–9) represented as 8×8 grayscale images. | 🌍 Real-world |
# | **Diabetes** | Regression | Linear Regression, Ridge, Lasso | Predict a quantitative measure of disease progression one year after baseline. | 🌍 Real-world |
# | **California Housing** | Regression | Linear Regression, Random Forest | Predict median house values in California districts using census data. | 🌍 Real-world |
# | **Linnerud** | Multivariate Regression | Linear Regression, PCA | Exercise physiological data — relate exercise stats to body measurements. | 🌍 Real-world |
# | **Boston Housing** ⚠️ *(deprecated)* | Regression | Linear Regression | Predict housing prices — deprecated due to ethical concerns and bias. | 🌍 Real-world |
# | **Make Classification** | Synthetic Dataset Generator | Binary / Multiclass Classification | Generate a customizable synthetic dataset for testing classifiers. | 🧪 Synthetic |
# | **Make Regression** | Synthetic Dataset Generator | Regression | Generate a random linear regression dataset with controlled noise. | 🧪 Synthetic |
# | **Make Blobs** | Synthetic Dataset Generator | Clustering, Classification | Create isotropic Gaussian blobs for clustering and classification. | 🧪 Synthetic |
# | **Make Moons** | Synthetic Dataset Generator | Binary Classification (Nonlinear) | Generate two interleaving moon-shaped classes — great for nonlinear models. | 🧪 Synthetic |
# | **Make Circles** | Synthetic Dataset Generator | Binary Classification (Nonlinear) | Generate concentric circle data — ideal for testing polynomial/logistic regression. | 🧪 Synthetic |
# | **Make Gaussian Quantiles** | Synthetic Dataset Generator | Binary / Multiclass Classification | Draw samples from multivariate normal distributions with class separation. | 🧪 Synthetic |
#
# ---
#
# ### 🧠 Tips:
# - ✅ Use **Real-world datasets** for *performance evaluation* and understanding generalization.
# - ⚙️ Use **Synthetic datasets** for *concept testing*, *visualization*, and *algorithm understanding*.
# - 🧩 All real-world datasets can be loaded using:
# ```python
#   from sklearn.datasets import load_iris, load_wine, load_breast_cancer
# ```
# ### 🧪 Synthetic datasets can be used dynamically
#
# ```python
#     from sklearn.datasets import make_moons, make_classification
#     X, y = make_moons(n_samples=300, noise=0.25, random_state=42)
#
# ```
