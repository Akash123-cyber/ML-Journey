# %% [markdown]
# # <center>📽️ **LOGISTIC REGRESSION**</center>
# ### <center>**(Binary Classification) (Multiple Input)**</center>
#
# ##### **🌟 NOTE :**
#
# ➡️ **Binary Classification Multiple Input don't have any sort of link to Multinomial Classification here we are just having a dataset with more than 1 predictor (multiplt inputs) but in Multinomial Classification we have more than 2 unordered categories in the target variable to predict/classify**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("ISplaced.csv")

# %%
dataset.head(3)
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1

# %%
sns.scatterplot(
    x = "cgpa",
    y = "resume_score",
    data = dataset,
    hue = "placed"
)
plt.legend()
plt.show()

# %%
x = dataset.iloc[:,:-1]
y = dataset["placed"]
x.ndim, y.ndim
# Out:
# (2, 1)

# %%
from sklearn.model_selection  import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lor = LogisticRegression()

# %%
lor.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lor.score(x_test,y_test)
# Out:
# 1.0

# %%
lor.predict([[8.14, 6.52]])
# Out:
# /home/akash/myEnv/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])

# %%
lor.coef_
# Out:
# array([[3.03417823, 0.49690768]])

# %%
lor.intercept_
# Out:
# array([-24.13435286])

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x.to_numpy(), y.to_numpy(), clf = lor )
plt.show()
# Out:
# /home/akash/myEnv/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
